# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/samplebankloandata.csv')

# %%
data.dtypes
# Out:
# id                        int64
# year                      int64
# issue_d                  object
# final_d                 float64
# emp_length_int          float64
# home_ownership           object
# home_ownership_cat      float64
# income_category          object
# annual_inc              float64
# income_cat              float64
# loan_amount             float64
# term                     object
# term_cat                float64
# application_type         object
# application_type_cat    float64
# purpose                  object
# purpose_cat             float64
# interest_payments        object
# interest_payment_cat    float64
# loan_condition           object
# loan_condition_cat      float64
# interest_rate           float64
# grade                    object
# grade_cat               float64
# dti                     float64
# total_pymnt             float64
# total_rec_prncp         float64
# recoveries              float64
# installment             float64
# region                   object
# dtype: object

# %%
data.head()
# Out:
#         id  year    issue_d    final_d  emp_length_int home_ownership  \
# 0  1077501  2011  12/1/2011  1012015.0            10.0           RENT
# 1  1077430  2011  12/1/2011  1042013.0             0.5           RENT
# 2  1077175  2011  12/1/2011  1062014.0            10.0           RENT
# 3  1076863  2011  12/1/2011  1012015.0            10.0           RENT
# 4  1075358  2011  12/1/2011  1012016.0             1.0           RENT
#
#    home_ownership_cat income_category  annual_inc  income_cat  ...  \
# 0                 1.0             Low     24000.0         1.0  ...
# 1                 1.0             Low     30000.0         1.0  ...
# 2                 1.0             Low     12252.0         1.0  ...
# 3                 1.0             Low     49200.0         1.0  ...
# 4                 1.0             Low     80000.0         1.0  ...
#
#    loan_condition_cat interest_rate  grade grade_cat    dti   total_pymnt  \
# 0                 0.0         10.65      B       2.0  27.65   5861.071414
# 1                 1.0         15.27      C       3.0   1.00   1008.710000
# 2                 0.0         15.96      C       3.0   8.72   3003.653644
# 3                 0.0         13.49      C       3.0  20.00  12226.302210
# 4                 0.0         12.69      B       2.0  17.94   3242.170000
#
#    total_rec_prncp recoveries  installment    region
# 0          5000.00       0.00       162.87   munster
# 1           456.46     117.08        59.83  leinster
# 2          2400.00       0.00        84.33  cannught
# 3         10000.00       0.00       339.31    ulster
# 4          2233.10       0.00        67.79    ulster
#
# [5 rows x 30 columns]

# %%
data.isnull().sum()
# Out:
# id                      0
# year                    0
# issue_d                 1
# final_d                 1
# emp_length_int          1
# home_ownership          1
# home_ownership_cat      1
# income_category         1
# annual_inc              1
# income_cat              1
# loan_amount             1
# term                    1
# term_cat                1
# application_type        1
# application_type_cat    1
# purpose                 1
# purpose_cat             1
# interest_payments       1
# interest_payment_cat    1
# loan_condition          1
# loan_condition_cat      1
# interest_rate           1
# grade                   1
# grade_cat               1
# dti                     1
# total_pymnt             1
# total_rec_prncp         1
# recoveries              1
# installment             1
# region                  1
# dtype: int64

# %%
data = data.dropna()

# %%
data['home_ownership'].value_counts()
# Out:
# home_ownership
# RENT        14234
# MORTGAGE    14218
# OWN          2285
# OTHER           1
# Name: count, dtype: int64

# %%
data['income_category'].value_counts()
# Out:
# income_category
# Low       26281
# Medium     4024
# High        433
# Name: count, dtype: int64

# %%
data['grade'].value_counts()
# Out:
# grade
# B    9188
# A    8009
# C    5827
# D    4054
# E    2438
# F     938
# G     284
# Name: count, dtype: int64

# %%
data['region'].value_counts()
# Out:
# region
# Northern-Irl    8222
# ulster          8003
# leinster        7031
# cannught        4335
# munster         3147
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x='grade')
plt.xticks(rotation=45)
plt.title("grade")
plt.show()

# %%
sns.countplot(data=data,x='home_ownership')
plt.xticks(rotation=45)
plt.title("Home ownership")
plt.show()

# %%
plt.pie(data['income_category'].value_counts(),labels=data['income_category'].value_counts().index,autopct='%1.1f%%')
plt.title('Income Category')
plt.show()

# %%
plt.pie(data['home_ownership'].value_counts(),labels=data['home_ownership'].value_counts().index,autopct='%1.1f%%')
plt.title('home_ownership')
plt.show()

# %%
plt.pie(data['region'].value_counts(),labels=data['region'].value_counts().index,autopct='%1.1f%%')
plt.title('Region')
plt.show()

# %%
df=data.copy()

# %%
df.head()
# Out:
#         id  year    issue_d    final_d  emp_length_int home_ownership  \
# 0  1077501  2011  12/1/2011  1012015.0            10.0           RENT
# 1  1077430  2011  12/1/2011  1042013.0             0.5           RENT
# 2  1077175  2011  12/1/2011  1062014.0            10.0           RENT
# 3  1076863  2011  12/1/2011  1012015.0            10.0           RENT
# 4  1075358  2011  12/1/2011  1012016.0             1.0           RENT
#
#    home_ownership_cat income_category  annual_inc  income_cat  ...  \
# 0                 1.0             Low     24000.0         1.0  ...
# 1                 1.0             Low     30000.0         1.0  ...
# 2                 1.0             Low     12252.0         1.0  ...
# 3                 1.0             Low     49200.0         1.0  ...
# 4                 1.0             Low     80000.0         1.0  ...
#
#    loan_condition_cat interest_rate  grade grade_cat    dti   total_pymnt  \
# 0                 0.0         10.65      B       2.0  27.65   5861.071414
# 1                 1.0         15.27      C       3.0   1.00   1008.710000
# 2                 0.0         15.96      C       3.0   8.72   3003.653644
# 3                 0.0         13.49      C       3.0  20.00  12226.302210
# 4                 0.0         12.69      B       2.0  17.94   3242.170000
#
#    total_rec_prncp recoveries  installment    region
# 0          5000.00       0.00       162.87   munster
# 1           456.46     117.08        59.83  leinster
# 2          2400.00       0.00        84.33  cannught
# 3         10000.00       0.00       339.31    ulster
# 4          2233.10       0.00        67.79    ulster
#
# [5 rows x 30 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
df['region']=lc.fit_transform(df['region'])

# %%
df.drop(['id', 'home_ownership', 'income_category','purpose','grade','loan_condition','term','interest_payments','application_type','application_type_cat','issue_d','final_d'],axis=1, inplace=True)

# %%
df.dtypes
# Out:
# year                      int64
# emp_length_int          float64
# home_ownership_cat      float64
# annual_inc              float64
# income_cat              float64
# loan_amount             float64
# term_cat                float64
# purpose_cat             float64
# interest_payment_cat    float64
# loan_condition_cat      float64
# interest_rate           float64
# grade_cat               float64
# dti                     float64
# total_pymnt             float64
# total_rec_prncp         float64
# recoveries              float64
# installment             float64
# region                    int64
# dtype: object

# %%
df
# Out:
#        year  emp_length_int  home_ownership_cat  annual_inc  income_cat  \
# 0      2011            10.0                 1.0     24000.0         1.0
# 1      2011             0.5                 1.0     30000.0         1.0
# 2      2011            10.0                 1.0     12252.0         1.0
# 3      2011            10.0                 1.0     49200.0         1.0
# 4      2011             1.0                 1.0     80000.0         1.0
# ...     ...             ...                 ...         ...         ...
# 30733  2010             0.5                 1.0     40000.0         1.0
# 30734  2010             5.0                 3.0    100000.0         1.0
# 30735  2010             2.0                 3.0     52000.0         1.0
# 30736  2010             3.0                 1.0     19968.0         1.0
# 30737  2010             6.0                 1.0     28800.0         1.0
#
#        loan_amount  term_cat  purpose_cat  interest_payment_cat  \
# 0           5000.0       1.0          1.0                   1.0
# 1           2500.0       2.0          2.0                   2.0
# 2           2400.0       1.0          3.0                   2.0
# 3          10000.0       1.0          4.0                   2.0
# 4           3000.0       2.0          4.0                   1.0
# ...            ...       ...          ...                   ...
# 30733       5000.0       1.0          6.0                   1.0
# 30734      11000.0       1.0          2.0                   1.0
# 30735      10000.0       1.0          3.0                   1.0
# 30736       4000.0       1.0          4.0                   2.0
# 30737       5000.0       1.0          6.0                   2.0
#
#        loan_condition_cat  interest_rate  grade_cat    dti   total_pymnt  \
# 0                     0.0          10.65        2.0  27.65   5861.071414
# 1                     1.0          15.27        3.0   1.00   1008.710000
# 2                     0.0          15.96        3.0   8.72   3003.653644
# 3                     0.0          13.49        3.0  20.00  12226.302210
# 4                     0.0          12.69        2.0  17.94   3242.170000
# ...                   ...            ...        ...    ...           ...
# 30733                 0.0          13.11        3.0   3.18   6071.930000
# 30734                 0.0           7.51        1.0   8.03  12103.670000
# 30735                 0.0           9.88        2.0  11.65  11582.370000
# 30736                 0.0          16.45        5.0   5.29   5091.200000
# 30737                 0.0          14.96        4.0  17.88   5986.890000
#
#        total_rec_prncp  recoveries  installment  region
# 0              5000.00        0.00       162.87       3
# 1               456.46      117.08        59.83       2
# 2              2400.00        0.00        84.33       1
# 3             10000.00        0.00       339.31       4
# 4              2233.10        0.00        67.79       4
# ...                ...         ...          ...     ...
# 30733          5000.00        0.00       168.73       0
# 30734         11000.00        0.00       342.21       0
# 30735         10000.00        0.00       322.11       0
# 30736          4000.00        0.00       141.51       3
# 30737          5000.00        0.00       173.24       0
#
# [30738 rows x 18 columns]

# %%
df['annual_inc'].plot(kind='line', figsize=(8, 4), title='annual_inc')
plt.show()

# %%
df.groupby('purpose_cat')['dti'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='purpose_cat'>

# %%
corr=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True,cmap='coolwarm',linewidths=2)
plt.title('Correlation Heat Map')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.scatterplot(data=df, x="grade_cat", y="interest_rate", hue="grade_cat")
plt.title("Interest Rate vs Grade Category")
plt.show()

# %%
import matplotlib.pyplot as plt
sns.scatterplot(data=df, x="loan_amount", y="installment")
plt.title("Interest Rate vs Grade Category")
plt.show()

# %%
cols_obj = []
for cols in data.columns:
  if data[cols].dtype == 'object':
    cols_obj.append(cols)

# %%
cols_obj
# Out:
# ['issue_d',
#  'home_ownership',
#  'income_category',
#  'term',
#  'application_type',
#  'purpose',
#  'interest_payments',
#  'loan_condition',
#  'grade',
#  'region']

# %%
data['loan_condition'].value_counts()
# Out:
# loan_condition
# Good Loan    26217
# Bad Loan      4521
# Name: count, dtype: int64

# %%
sns.boxplot(data=df,x='loan_condition_cat',y='loan_amount')
plt.show()
